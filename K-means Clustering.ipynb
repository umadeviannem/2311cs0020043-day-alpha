# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans

# %% [markdown]
# #### Clustering-Divide the universities to groups(Clusters)

# %%
Univ = pd.read_csv("Universities (2).csv")
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
Univ.isna().sum()
# Out:
# Univ        0
# SAT         0
# Top10       0
# Accept      0
# SFRatio     0
# Expenses    0
# GradRate    0
# dtype: int64

# %%
Univ.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %% [markdown]
# #### Standardization of the data

# %%
# Read all numeric columns in  to Univ1
Univ1 = Univ.iloc[:,1:]

# %%
Univ1
# Out:
#      SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   1310     89      22       13     22704        94
# 1   1415    100      25        6     63575        81
# 2   1260     62      59        9     25026        72
# 3   1310     76      24       12     31510        88
# 4   1280     83      33       13     21864        90
# 5   1340     89      23       10     32162        95
# 6   1315     90      30       12     31585        95
# 7   1255     74      24       12     20126        92
# 8   1400     91      14       11     39525        97
# 9   1305     75      44        7     58691        87
# 10  1380     94      30       10     34870        91
# 11  1260     85      39       11     28052        89
# 12  1255     81      42       13     15122        94
# 13  1081     38      54       18     10185        80
# 14  1375     91      14        8     30220        95
# 15  1005     28      90       19      9066        69
# 16  1360     90      20       12     36450        93
# ...

# %%
cols = Univ1.columns

# %%
# Standarisation function
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_Univ_df = pd.DataFrame(scaler.fit_transform(Univ1),columns = cols)
scaled_Univ_df
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0   0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# 1   1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# 2  -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# 3   0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# 4   0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# 5   0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# 6   0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# 7  -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# 8   1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# 9   0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# 10  1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# 11 -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# 12 -0.107751  0.237379  0.144862  0.070260 -0.867871  0.820303
# 13 -1.746625 -2.020875  0.765699  1.324911 -1.217184 -0.757202
# ...

# %%
# Build 3 Clusters using KMeans Cluster algorith
from sklearn.cluster import KMeans
clusters_new = KMeans(3, random_state=0)
clusters_new.fit(scaled_Univ_df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# print the cluster labels
clusters_new.labels_
# Out:
# array([1, 2, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1, 0, 1, 0, 1, 0, 1, 1, 0, 1,
#        1, 0, 1])

# %%
set(clusters_new.labels_)
# Out:
# {0, 1, 2}

# %%
# Assign clusters to the Univ data set
Univ['clusterid_new'] = clusters_new.labels_

# %%
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
Univ[Univ['clusterid_new']==1]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# 14     Princeton  1375     91      14        8     30220        95
# 16      Stanford  1360     90      20       12     36450        93
# ...

# %%
# Use groupby() to find aggregated (mean) values in each cluster
Univ.iloc[:,1:].groupby("clusterid_new").mean()
# Out:
#                        SAT      Top10     Accept    SFRatio      Expenses  \
# clusterid_new
# 0              1085.200000  44.000000  69.600000  18.600000  11056.400000
# 1              1306.388889  84.277778  31.277778  11.777778  28175.111111
# 2              1360.000000  87.500000  34.500000   6.500000  61133.000000
#
#                 GradRate  Clusterid_new
# clusterid_new
# 0              74.400000            0.0
# 1              90.444444            1.0
# 2              84.000000            2.0

# %% [markdown]
# #### Observations:
# - Cluster 2 appears to be top rated universities cluster as the cutoff score, Top 10, SFRatio parameters mean values are highest
# - Cluster 1 appears to occupy the middle level rated universities
# - Cluster 0 comes as the lowesr level rated universities

# %% [markdown]
# #### Finding optimal k value using elbow plot

# %%
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(scaled_Univ_df)
    wcss.append(kmeans.inertia_)
print(wcss)
plt.plot(range(1, 20), wcss)
plt.title('Elbow  Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# [149.99999999999997, 64.14528395010268, 49.69054164653249, 34.79612750585775, 28.96866904732409, 25.012005085561192, 22.05883596374174, 17.50346369017422, 14.550294568354765, 11.534641754172174, 9.913351835524065, 8.821807244629866, 7.105666946966511, 6.1110919118148646, 3.6133492318650804, 2.92982295909539, 2.601273981139519, 2.1199139898076513, 1.6797535810239916]
